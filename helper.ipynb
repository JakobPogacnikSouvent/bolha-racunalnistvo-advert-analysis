# %%
import io

# %%
DATOTEKA = "data"
with io.open(f"{DATOTEKA}.csv", "r", encoding="utf-8") as File, io.open(f"{DATOTEKA}_popravljena.csv", "w", encoding="utf-8") as Out_File:
    for line in File:
        print()
        if line.strip().count(";") == 3:
            Out_File.write(line.replace(";", ";;;"))
        else:
            Out_File.write("MANUAL FIX NEEDED\n")
